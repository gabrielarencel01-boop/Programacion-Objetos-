# %%
import pandas as pd
df=pd.read_csv("complete_results.csv")
df
# Out:
#                                                    name        main_category  \
# 0     Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  tv, audio & cameras
# 1     OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  tv, audio & cameras
# 2     OnePlus Bullets Z2 Bluetooth Wireless in Ear E...  tv, audio & cameras
# 3     Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  tv, audio & cameras
# 4     OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  tv, audio & cameras
# ...                                                 ...                  ...
# 5005  ASUS MD100 Marshmallow/Silent, Adj. DPI, Multi...  tv, audio & cameras
# 5006  Crysendo Headphone Cushion Pad Compatible with...  tv, audio & cameras
# 5007  VOYEE Controller for PC, Wired Gamepad, Gaming...  tv, audio & cameras
# 5008  boAt Airdopes 393ANC True Wireless in Ear Earb...  tv, audio & cameras
# 5009  Quess Care Total Protection Plan for 1 Year Pr...  tv, audio & cameras
#
# ...

# %%
df.head()
# Out:
#                                                 name        main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  tv, audio & cameras
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  tv, audio & cameras
# 2  OnePlus Bullets Z2 Bluetooth Wireless in Ear E...  tv, audio & cameras
# 3  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  tv, audio & cameras
# 4  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  tv, audio & cameras
#
#       sub_category                                              image  \
# 0  All Electronics  https://m.media-amazon.com/images/I/81eM15lVcJ...
# 1  All Electronics  https://m.media-amazon.com/images/I/71AvQd3Vzq...
# 2  All Electronics  https://m.media-amazon.com/images/I/51UhwaQXCp...
# 3  All Electronics  https://m.media-amazon.com/images/I/81I3w4J6yj...
# 4  All Electronics  https://m.media-amazon.com/images/I/71V--WZVUI...
#
#                                                 link no_of_ratings  \
# ...

# %%
df.tail()
# Out:
#                                                    name        main_category  \
# 5005  ASUS MD100 Marshmallow/Silent, Adj. DPI, Multi...  tv, audio & cameras
# 5006  Crysendo Headphone Cushion Pad Compatible with...  tv, audio & cameras
# 5007  VOYEE Controller for PC, Wired Gamepad, Gaming...  tv, audio & cameras
# 5008  boAt Airdopes 393ANC True Wireless in Ear Earb...  tv, audio & cameras
# 5009  Quess Care Total Protection Plan for 1 Year Pr...  tv, audio & cameras
#
#          sub_category                                              image  \
# 5005  All Electronics  https://m.media-amazon.com/images/I/61hXCL4uC7...
# 5006  All Electronics  https://m.media-amazon.com/images/I/51ODZvKNuS...
# 5007  All Electronics  https://m.media-amazon.com/images/I/61E7Kdsa1k...
# 5008  All Electronics  https://m.media-amazon.com/images/W/IMAGERENDE...
# 5009  All Electronics  https://m.media-amazon.com/images/W/IMAGERENDE...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5010 entries, 0 to 5009
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     5010 non-null   str
#  1   main_category            5010 non-null   str
#  2   sub_category             5010 non-null   str
#  3   image                    5010 non-null   str
#  4   link                     5010 non-null   str
#  5   no_of_ratings            4976 non-null   str
#  6   discount_price           4740 non-null   str
#  7   actual_price             4979 non-null   str
#  8   review_rating            5010 non-null   str
#  9   original_review_text     5007 non-null   str
#  10  bart_summary             5007 non-null   str
#  11  bart_rouge1              5010 non-null   float64
#  12  bart_rouge2              5010 non-null   float64
#  13  bart_rougeL              5010 non-null   float64
# ...

# %%
df.shape
# Out:
# (5010, 26)

# %%
df.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'image', 'link',
#        'no_of_ratings', 'discount_price', 'actual_price', 'review_rating',
#        'original_review_text', 'bart_summary', 'bart_rouge1', 'bart_rouge2',
#        'bart_rougeL', 'bart_avg_rouge', 't5_summary', 't5_rouge1', 't5_rouge2',
#        't5_rougeL', 't5_avg_rouge', 'best_model', 'raw_best_summary',
#        'best_avg_score', 'cleaned_narrative', 'qwen_used',
#        'processing_time_seconds'],
#       dtype='str')

# %%
df["name"].unique()
# Out:
# <StringArray>
# [                                                                         'Redmi 10 Power (Power Black, 8GB RAM, 128GB Storage)',
#                                                                  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM, 128GB Storage)',
#  'OnePlus Bullets Z2 Bluetooth Wireless in Ear Earphones with Mic, Bombastic Bass - 12.4 Mm Drivers, 10 Mins Charge - 20 Hrs...',
#  'Samsung Galaxy M33 5G (Mystique Green, 6GB, 128GB Storage) | 6000mAh Battery | Upto 12GB RAM with RAM Plus | Travel Adapte...',
#                                                                 'OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM, 128GB Storage)',
#                                                                         'Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB Storage)',
#  'boAt Airdopes 141 Bluetooth Truly Wireless in Ear Earbuds with mic, 42H Playtime, Beast Mode(Low Latency Upto 80ms) for Ga...',
# ...
